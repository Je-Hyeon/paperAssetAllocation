# %%
import json
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
best_k = pd.read_pickle("results/res2/best_k_concat.pkl")

# %%
best_k.resample("W").last().plot(figsize=(14,6), fontsize=13)
# Out:
# <Axes: >
