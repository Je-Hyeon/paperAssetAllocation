# %% [markdown]
# 구글 스칼라 인용수 정렬
#
# - 내가 직접 만든다

# %%
import requests
import random
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
headers = {
    "authority": "scholar.google.com",
    "method": "GET",
    "path": "/scholar?hl=en&as_sdt=0%2C5&q=%22black%22%2C+%22litterman%22&btnG=",
    "scheme": "https",
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "cache-control": "no-cache",
    "cookie": "",
    "pragma": "no-cache",
    "priority": "u=0, i",
    "referer": "https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=black+litterman&btnG=",
    "sec-ch-ua": '"Not)A;Brand";v="8", "Chromium";v="138", "Google Chrome";v="138"',
    "sec-ch-ua-arch": "x86",
    "sec-ch-ua-bitness": "64",
    "sec-ch-ua-full-version-list": '"Not)A;Brand";v="8.0.0.0", "Chromium";v="138.0.7204.51", "Google Chrome";v="138.0.7204.51"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-model": "",
    "sec-ch-ua-platform": "Windows",
    "sec-ch-ua-platform-version": "19.0.0",
    "sec-ch-ua-wow64": "?0",
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "same-origin",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
    "x-browser-channel": "stable",
    "x-browser-copyright": "Copyright 2025 Google LLC. All rights reserved.",
    "x-browser-validation": "6h3XF8YcD8syi2FF2BbuE2KllQo=",
    "x-browser-year": "2025",
    "x-client-data": "CIu2yQEIpLbJAQipncoBCLHuygEIk6HLAQijo8sBCIWgzQEI/qXOAQji8M4BCKTyzgEIk/bOAQir+c4BGND6zgE=",
}

# %%
def search_scholar_papers(query, num_pages=1, headers=None):
    """
    Google Scholar에서 논문 정보를 여러 페이지에 걸쳐 수집하는 함수입니다.
    각 페이지는 10개의 논문을 포함합니다.

    Args:
        query (str): 검색할 쿼리 (예: "mean+variance+optimization")
        num_pages (int): 가져올 페이지 수 (기본값: 1)
        headers (dict): requests에 사용할 헤더 (기본값: None)

    Returns:
        list: 논문 정보가 담긴 딕셔너리 리스트
    """
    papers = []
    for page in tqdm(range(num_pages)):
        time.sleep(random.uniform(1.5, 5.5))
        start = page * 10
        url = f"https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q={query}&start={start}&btnG="
        req = requests.get(url, headers=headers)
        soup = BeautifulSoup(req.text, "html.parser")

        for item in soup.find_all("div", class_="gs_ri"):
            # 논문 제목 추출
            title_tag = item.find("h3", class_="gs_rt")
            if title_tag and title_tag.a:
                title = title_tag.a.get_text()
                paper_url = title_tag.a.get("href", "")
            else:
                title = title_tag.get_text() if title_tag else ""
                paper_url = ""
            
            # 저자, 저널, 연도, 웹사이트 분리 추출 (\xa0 기준 분리)
            journal_info = item.find("div", class_="gs_a")
            author = ""
            journal = ""
            year = ""
            website = ""
            if journal_info:
                journal_raw = journal_info.get_text()
                # \xa0로 분리
                parts = journal_raw.split('\xa0- ')
                if len(parts) >= 2:
                    author = parts[0].strip()
                    # 저널, 연도, 웹사이트는 두 번째 파트에 있음
                    rest = parts[1]
                    # 쉼표로 분리해서 연도 찾기
                    rest_parts = rest.split(',')
                    if len(rest_parts) >= 2:
                        # 마지막 쉼표 뒤에 연도와 웹사이트가 있을 수 있음
                        journal = ','.join(rest_parts[:-1]).strip()
                        last_part = rest_parts[-1].strip()
                        # 마지막 파트에서 연도와 웹사이트 분리
                        if '-' in last_part:
                            year_website = last_part.split('-')
                            year = year_website[0].strip()
                            website = year_website[1].strip() if len(year_website) > 1 else ""
                        else:
                            year = last_part
                    else:
                        # 쉼표가 없으면 그냥 전체를 journal로
                        journal = rest.strip()
                else:
                    # \xa0- 가 없으면 전체를 journal로
                    journal = journal_raw.strip()
            
            # 인용 횟수 추출
            cited_tag = item.find("a", string=lambda s: s and "Cited by" in s)
            if cited_tag:
                try:
                    cited_count = int(cited_tag.get_text().split("Cited by")[-1].strip())
                except:
                    cited_count = 0
            else:
                cited_count = 0

            papers.append({
                "title": title,
                "author": author,
                "journal": journal,
                "year": year,
                "website": website,
                "url": paper_url,
                "cited_count": cited_count
            })
    return papers

# 사용 예시:
# papers = search_scholar_papers("mean+variance+optimization", num_pages=3, headers=headers)
# papers 리스트에 논문 제목, 저자, 저널/학회명, 연도, 웹사이트, 논문 URL, 인용 횟수가 담깁니다.

# %%
papers = search_scholar_papers("mean+variance+optimization", num_pages=10, headers=headers)
# Out:
# 100%|██████████| 10/10 [00:46<00:00,  4.62s/it]

# %%
df = pd.DataFrame(papers)

# %%
df.sort_values(by="cited_count", ascending=False).drop("website", axis=1).head(40)
# Out:
#                                                 title  \
# 55  Continuous-time mean-variance portfolio select...
# 89         A mean/variance analysis of tracking error
# 60             Dynamic mean-variance asset allocation
# 7   Mean–variance portfolio optimization with stat...
# 17  In search of the exchange risk premium: A six-...
# 35   Mean–variance approximations to expected utility
# 87  Mean–variance portfolio optimization using mac...
# 49  A mean-variance-skewness portfolio optimizatio...
# 6   The mean-variance approach to portfolio optimi...
# 51  The mean–variance cardinality constrained port...
# 14  A geometric approach to multiperiod mean varia...
# 20  A comprehensive review of deterministic models...
# 81  Mean-semivariance optimization: A heuristic ap...
# 33  Asset and liability management under a continu...
# 83  Portfolio selection problems with Markowitz's ...
# 0              A mean-variance optimization algorithm
# 19  Multiperiod portfolio optimization models in s...
# 62  Approaching mean-variance efficiency for large...
# 46  Mean-variance-skewness-kurtosis-based portfoli...
# 34        Mean/variance analysis of currency overlays
# 3   Mean-variance optimization in Markov decision ...
# 31  A new method for mean-variance portfolio optim...
# 67  Firefly Algorithm for Cardinality Constrained ...
# 16  Mean–variance portfolio optimization when mean...
# 10  Robust empirical optimization is almost the sa...
# 30  Worst-case robust decisions for multi-period m...
# 12  Mean-variance model for portfolio optimization...
# 13  The implications of mean-variance optimization...
# 8   The mean–variance-optimization puzzle: Securit...
# 2   Financial optimization in the Turkish electric...
# 5   Improving mean variance optimization through s...
# 85  Mean-variance model for power system economic ...
# 38           Mean–variance optimal adaptive execution
# 93  What is the opportunity cost of mean-variance ...
# 50  Mean–variance versus full-scale optimisation: ...
# 45  Multi-period mean–variance portfolio optimizat...
# 90  Markowitz mean-variance portfolio optimization...
# 74  Multi-period mean–variance fuzzy portfolio opt...
# 23  A mean–variance objective for robust productio...
# 44  Exploring the mean-variance portfolio optimiza...
#
#                                                author  \
# 55                                      XY Zhou, D Li
# 89
# 60                              S Basak, G Chabakauri
# 7                         T Björk, A Murgoci, XY Zhou
# 17                                         JA Frankel
# 35                                        H Markowitz
# 87                W Chen, H Zhang, MK Mehlawat, L Jia
# 49                                  H Konno, K Suzuki
# 6                                         A Yoshimoto
# 51                      KP Anagnostopoulos, G Mamanis
# 14                    M Leippold, F Trojani, P Vanini
# 20                  CB Kalayci, O Ertenlice, MA Akbay
# 81                                          J Estrada
# 33                                      MC Chiu, D Li
# 83                               Y Zhang, X Li, S Guo
# 0                       I Erlich, GK Venayagamoorthy…
# 19                             U Celikyurt, S Özekici
# 62                          M Ao, L Yingying, X Zheng
# 46                               KK Lai, L Yu, S Wang
# 34                                           P Jorion
# 3                              S Mannor, J Tsitsiklis
# 31                 F Cesarone, A Scozzari, F Tardella
# 67                                  N Bacanin, M Tuba
# 16
# 10                           J Gotoh, MJ Kim, AEB Lim
# 30                               N Gülpınar, B Rustem
# 12                                              Z Qin
# 13                                         JA Frankel
# 8                                KL Fisher, M Statman
# 2                                 F Gökgöz, ME Atmaca
# 5                                        S Goto, Y Xu
# 85                       YZ Li, QH Wu, MS Li, JP Zhan
# 38                                J Lorenz, R Almgren
# 93                                           Y Simaan
# 50                                T Adler, M Kritzman
# 45                               F Cong, CW Oosterlee
# 90                        A Chaweewanchon, R Chaysiri
# 74                         K Liagkouras, K Metaxiotis
# 23                    A Capolei, E Suwartadi, B Foss…
# 44  FJ Santos-Alamillos, NS Thomaidis, J Usaola-Ga...
#
#                                               journal  year  \
# 55               Applied Mathematics and Optimization  2000
# 89                  R Roll - 1992 - anderson.ucla.edu
# 60                    The Review of Financial Studies  2010
# 7                          Mathematical Finance: An …  2014
# 17         Journal of international Money and Finance  1982
# 35           European Journal of Operational Research  2014
# 87                             Applied soft computing  2021
# 49    Journal of the Operations Research Society of …  1995
# 6   Journal of the Operations Research Society of ...  1996
# 51                   Expert Systems with Applications  2011
# 14                 Journal of Economic Dynamics and …  2004
# 20                   Expert Systems with Applications  2019
# 81   Journal of Applied Finance (Formerly Financial …  2008
# 33               Insurance: Mathematics and Economics  2006
# 83             Fuzzy Optimization and Decision Making  2018
# 0                                  IEEE Congress on …  2010
# 19           European Journal of Operational Research  2007
# 62                    The Review of Financial Studies  2019
# 46          First International Multi-Symposiums on …  2006
# 34                         Financial Analysts Journal  1994
# 3                      arXiv preprint arXiv:1104.5601  2011
# 31                      Annals of Operations Research  2013
# 67                       The Scientific World Journal  2014
# 16  TL Lai, H Xing, Z Chen - 2011 - projecteuclid.org
# 10                        Operations research letters  2018
# 30           European Journal of Operational Research  2007
# 12           European Journal of Operational Research  2015
# 13         Journal of International Money and Finance  1986
# 8                          Financial Analysts Journal  1997
# 2            Renewable and Sustainable Energy Reviews  2012
# 5      Journal of Financial and Quantitative Analysis  2015
# 85                                             Energy  2014
# 38                       Applied Mathematical Finance  2011
# 93                                 Management Science  1993
# 50                        Journal of Asset Management  2007
# 45           Journal of Economic Dynamics and Control  2016
# 90               International Journal of Financial …  2022
# 74           Engineering applications of artificial …  2018
# 23                             Journal of Petroleum …  2015
# 44                                   Renewable Energy  2017
#
#                                                   url  cited_count
# 55  https://link.springer.com/article/10.1007/s002...         1345
# 89  https://www.anderson.ucla.edu/documents/areas/...         1162
# 60  https://academic.oup.com/rfs/article-abstract/...          700
# 7   https://onlinelibrary.wiley.com/doi/abs/10.111...          591
# 17  https://www.sciencedirect.com/science/article/...          498
# 35  https://www.sciencedirect.com/science/article/...          384
# 87  https://www.sciencedirect.com/science/article/...          335
# 49  https://www.jstage.jst.go.jp/article/jorsj/38/...          327
# 6   https://www.jstage.jst.go.jp/article/jorsj/39/...          318
# 51  https://www.sciencedirect.com/science/article/...          272
# 14  https://www.sciencedirect.com/science/article/...          244
# 20  https://www.sciencedirect.com/science/article/...          228
# 81  https://papers.ssrn.com/sol3/papers.cfm?abstra...          219
# 33  https://www.sciencedirect.com/science/article/...          211
# 83  https://link.springer.com/article/10.1007/s107...          210
# 0   https://ieeexplore.ieee.org/abstract/document/...          199
# 19  https://www.sciencedirect.com/science/article/...          184
# 62  https://academic.oup.com/rfs/article-abstract/...          179
# 46  https://ieeexplore.ieee.org/abstract/document/...          176
# 34  https://www.tandfonline.com/doi/pdf/10.2469/fa...          168
# 3                     https://arxiv.org/abs/1104.5601          154
# 31  https://link.springer.com/article/10.1007/s104...          154
# 67  https://onlinelibrary.wiley.com/doi/abs/10.115...          144
# 16  https://projecteuclid.org/journals/annals-of-a...          140
# 10  https://www.sciencedirect.com/science/article/...          140
# 30  https://www.sciencedirect.com/science/article/...          139
# 12  https://www.sciencedirect.com/science/article/...          135
# 13  https://www.sciencedirect.com/science/article/...          125
# 8   https://www.tandfonline.com/doi/abs/10.2469/fa...          116
# 2   https://www.sciencedirect.com/science/article/...          109
# 5   https://www.cambridge.org/core/journals/journa...          107
# 85  https://www.sciencedirect.com/science/article/...          107
# 38  https://www.tandfonline.com/doi/abs/10.1080/13...          106
# 93  https://pubsonline.informs.org/doi/abs/10.1287...          103
# 50  https://link.springer.com/article/10.1057/palg...          103
# 45  https://www.sciencedirect.com/science/article/...           97
# 90             https://www.mdpi.com/2227-7072/10/3/64           93
# 74  https://www.sciencedirect.com/science/article/...           89
# 23  https://www.sciencedirect.com/science/article/...           80
# 44  https://www.sciencedirect.com/science/article/...           76
